# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pill.csv')
df.drop(columns=['Unnamed: 0', 'itemSeq', 'itemImage', 'openDe', 'updateDe'], inplace=True)

df.head()
# Out:
#   entpName                          itemName  \
# 0    동화약품주                               활명수
# 1    신신제약주  신신티눈고살리실산반창고수출명SINSINCORNPLASTER
# 2    삼진제약주                              아네모정
# 3    동아제약주                타치온정50밀리그램글루타티온환원형
# 4      주보령                     겔포스현탁액인산알루미늄겔
#
#                                           efcyQesitm  \
# 0        이 약은 식욕감퇴식욕부진 위부팽만감 소화불량 과식 체함 구역 구토에 사용합니다
# 1                           이 약은 티눈 못굳은살 사마귀에 사용합니다
# 2   이 약은 위산과다 속쓰림 위부불쾌감 위부팽만감 체함 구역 구토 위통 신트림에 사용합니다
# 3                              이 약은 약물중독 자가중독에 사용합니다
# 4  이 약은 위십이지장 궤양 위염 위산과다속쓰림 위통 구역 구토의 제산작용 및 증상의 ...
#
#                                      useMethodQesitm atpnWarnQesitm  \
# 0  만 15세 이상 및 성인은 1회 1병75 mL 만 11세이상만 15세미만은 1회 2...            NaN
# 1  이형지로부터 벗겨 이 약제면을 환부질환 부위에 대고 테이프로 고정하고 25일마다 교...            NaN
# 2           성인 1회 2정 1일 3회 식간식사와 식사때 사이 및 취침시에 복용합니다            NaN
# 3  성인은 1회 12정50100 mg 1일 13회 복용합니다연령 증상에 따라 적절히 증...            NaN
# 4  성인은 1회 1포 1일 34회 식간식사때와 식사때 사이 및 취침시 복용합니다연령 또...            NaN
#
#                                           atpnQesitm  \
# 0  만 3개월 미만의 젖먹이는 이 약을 복용하지 마십시오. 이 약을 복용하기 전에 만 ...
# 1  이 약에 과민증 환자 당뇨병 혈액순환장애 환자는 이 약을 사용하지 마십시오. 눈 주...
# 2  투석요법을 받고 있는 환자 수유부 만 7세 이하의 어린이 갈락토오스 불내성 Lapp...
# 3                                                NaN
# 4          이 약을 복용하기 전에 신장장애 변비 환자는 의사 또는 약사와 상의하십시오
#
#                                          intrcQesitm  \
# 0                                                NaN
# 1  메토트렉세이트 설포닐우레아 다른 국소 적용 약물과 함께 사용 시 의사 또는 약사와 ...
# 2                위장진통ㆍ진경제 테트라사이클린계 항생제와 함께 복용하지 마십시오
# 3                                                NaN
# 4                        테트라사이클린계 항생물질과 함께 사용하지 마십시오
#
#                                             seQesitm  \
# 0                                                NaN
# 1  발진 발적충혈되어 붉어짐 홍반붉은 반점 가려움 정상 피부에 닿았을 경우 국소 자극 ...
# 2  발진 충혈되어 붉어짐 가려움 드물게 입이 마르는 증상 변비 또는 설사 등이 나타나는...
# 3  드물게 발진 식욕부진 구역 구토 위통 등이 나타나는 경우 복용을 즉각 중지하고 의사...
# 4                                   변비 등이 나타날 수 있습니다
#
#                               depositMethodQesitm
# 0  습기와 빛을 피해 실온에서 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오
# 1       습기와 빛을 피해 보관하십시오. 어린이의 손이 닿지 않는 곳에 보관하십시오
# 2         습기와 빛을 피해 보관하십시오어린이의 손이 닿지 않는 곳에 보관하십시오
# 3              실온에서 보관하십시오어린이의 손이 닿지 않는 곳에 보관하십시오
# 4                               빛을 피해 실온에서 보관하십시오

# %%
pills = df['itemName'].values.tolist()

for item in PILLS:
    if '인산' in item:
        print(item)
# Out:
# 겔포스현탁액인산알루미늄겔
# 투렌정벤프로페린인산염
# 렉크린액인산나트륨에네마
# 코프렐정벤프로페린인산염
